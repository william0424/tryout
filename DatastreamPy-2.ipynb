# %%
# %pip install magpi DatastreamPy
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Looking in indexes: http://repo.pgds.local/api/pypi/mgprupypi/simple
# Collecting magpi
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/magpi/2.0.30/magpi-2.0.30-py3-none-any.whl (21 kB)
# Collecting DatastreamPy
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/78/71/f6f751ff0078e18448307d3ac0b4a7b53f243d75febb3244acfdcff4aa4e/DatastreamPy-2.0.30-py3-none-any.whl (51 kB)
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.8/site-packages (from DatastreamPy) (2.0.3)
# Requirement already satisfied: requests in /databricks/python3/lib/python3.8/site-packages (from DatastreamPy) (2.32.3)
# Collecting requests-mock
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/97/ec/889fbc557727da0c34a33850950310240f2040f3b1955175fdb2b36a8910/requests_mock-1.12.1-py2.py3-none-any.whl (27 kB)
# Collecting msal
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/04/bf/81516b9aac7fd867709984d08eb4db1d2e3fe1df795c8e442cde9b568962/msal-1.32.3-py3-none-any.whl (115 kB)
# Collecting databricks-api
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/d0/cc/6c3f9cd8b2b6c7a45c95b94d334bc51f1579d875bbfac0ecb8accdb2f756/databricks_api-0.9.0-py3-none-any.whl (7.4 kB)
# Collecting adal
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/49/8d/58008a9a86075827f99aa8bb75d8db515bb9c34654f95e647cda31987db7/adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Requirement already satisfied: chardet in /databricks/python3/lib/python3.8/site-packages (from magpi) (3.0.4)
# Collecting databricks-cli
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/ae/a3/d56f8382c40899301f327d1c881278b09c9b8bc301c2c111633a0346d06e/databricks_cli-0.18.0-py2.py3-none-any.whl (150 kB)
# Collecting click
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/7e/d4/7ebdbd03970677812aac39c869717059dbb71a4cfc033ca6e5221787892c/click-8.1.8-py3-none-any.whl (98 kB)
# Collecting requests-oauthlib
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/3b/5d/63d4ae3b9daea098d5d6f5da83984853c1bbacd5dc826764b249fe119d24/requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting cryptography
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/25/50/c0dfb9d87ae88ccc01aad8eb93e23cfbcea6a6a106a9b63a7b14c1f93c75/cryptography-44.0.3-cp37-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
# Collecting PyJWT&lt;3,&gt;=1.0.0
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/79/84/0fdf9b18ba31d69877bd39c9cd6052b47f3761e9910c15de788e519f079f/PyJWT-2.9.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: python-dateutil&lt;3,&gt;=2.1.0 in /databricks/python3/lib/python3.8/site-packages (from adal-&gt;magpi) (2.9.0.post0)
# Requirement already satisfied: cffi&gt;=1.12 in /databricks/python3/lib/python3.8/site-packages (from cryptography-&gt;magpi) (1.14.5)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.8/site-packages (from cffi&gt;=1.12-&gt;cryptography-&gt;magpi) (2.20)
# Requirement already satisfied: six&gt;=1.5 in /databricks/python3/lib/python3.8/site-packages (from python-dateutil&lt;3,&gt;=2.1.0-&gt;adal-&gt;magpi) (1.15.0)
# Requirement already satisfied: idna&lt;4,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests-&gt;DatastreamPy) (2.10)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests-&gt;DatastreamPy) (2020.12.5)
# Requirement already satisfied: charset-normalizer&lt;4,&gt;=2 in /databricks/python3/lib/python3.8/site-packages (from requests-&gt;DatastreamPy) (3.4.2)
# Requirement already satisfied: urllib3&lt;3,&gt;=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests-&gt;DatastreamPy) (1.25.11)
# Collecting oauthlib&gt;=3.1.0
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/7e/80/cab10959dc1faead58dc8384a781dfbf93cb4d33d50988f7a69f1b7c9bbe/oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting tabulate&gt;=0.7.7
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/40/44/4a5f08c96eb108af5cb50b41f76142f0afa346dfa99d5296fe7202a11854/tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting urllib3&lt;3,&gt;=1.21.1
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/ce/d9/5f4c13cecde62396b0d3fe530a50ccea91e7dfc1ccf0e09c228841bb5ba8/urllib3-2.2.3-py3-none-any.whl (126 kB)
# Requirement already satisfied: numpy&gt;=1.20.3 in /databricks/python3/lib/python3.8/site-packages (from pandas-&gt;DatastreamPy) (1.22.4)
# Requirement already satisfied: pytz&gt;=2020.1 in /databricks/python3/lib/python3.8/site-packages (from pandas-&gt;DatastreamPy) (2020.5)
# Requirement already satisfied: tzdata&gt;=2022.1 in /databricks/python3/lib/python3.8/site-packages (from pandas-&gt;DatastreamPy) (2025.2)
# Installing collected packages: urllib3, tabulate, PyJWT, oauthlib, cryptography, click, databricks-cli, requests-oauthlib, requests-mock, msal, databricks-api, adal, magpi, DatastreamPy
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.11
#     Not uninstalling urllib3 at /databricks/python3/lib/python3.8/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-e950ac0f-d7a1-4bd2-ac8d-a26ee1eae11e
#     Can&#39;t uninstall &#39;urllib3&#39;. No files were found to uninstall.
# ERROR: pip&#39;s dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# botocore 1.19.7 requires urllib3&lt;1.26,&gt;=1.25.4; python_version != &#34;3.4&#34;, but you have urllib3 2.2.3 which is incompatible.
# Successfully installed DatastreamPy-2.0.30 PyJWT-2.9.0 adal-1.2.7 click-8.1.8 cryptography-44.0.3 databricks-api-0.9.0 databricks-cli-0.18.0 magpi-2.0.30 msal-1.32.3 oauthlib-3.2.2 requests-mock-1.12.1 requests-oauthlib-2.0.0 tabulate-0.9.0 urllib3-2.2.3
# Python interpreter will be restarted.
# </div>

# %%
# %run /RiskAndPerformanceIT/prod/Utils/UtilityFunctions
# Out:
# ###Set of Utility Functions
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Looking in indexes: http://repo.pgds.local/api/pypi/mgprupypi/simple
# Collecting termcolor
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/d9/5f/8c716e47b3a50cbd7c146f45881e11d9414def768b7cd9c5e6650ec2a80a/termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Installing collected packages: termcolor
# Successfully installed termcolor-2.4.0
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Looking in indexes: http://repo.pgds.local/api/pypi/mgprupypi/simple
# Requirement already satisfied: msal in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e950ac0f-d7a1-4bd2-ac8d-a26ee1eae11e/lib/python3.8/site-packages (1.32.3)
# Requirement already satisfied: PyJWT[crypto]&lt;3,&gt;=1.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e950ac0f-d7a1-4bd2-ac8d-a26ee1eae11e/lib/python3.8/site-packages (from msal) (2.9.0)
# Requirement already satisfied: requests&lt;3,&gt;=2.0.0 in /databricks/python3/lib/python3.8/site-packages (from msal) (2.32.3)
# Requirement already satisfied: cryptography&lt;47,&gt;=2.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e950ac0f-d7a1-4bd2-ac8d-a26ee1eae11e/lib/python3.8/site-packages (from msal) (44.0.3)
# Requirement already satisfied: cffi&gt;=1.12 in /databricks/python3/lib/python3.8/site-packages (from cryptography&lt;47,&gt;=2.5-&gt;msal) (1.14.5)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.8/site-packages (from cffi&gt;=1.12-&gt;cryptography&lt;47,&gt;=2.5-&gt;msal) (2.20)
# Requirement already satisfied: idna&lt;4,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests&lt;3,&gt;=2.0.0-&gt;msal) (2.10)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests&lt;3,&gt;=2.0.0-&gt;msal) (2020.12.5)
# Requirement already satisfied: charset-normalizer&lt;4,&gt;=2 in /databricks/python3/lib/python3.8/site-packages (from requests&lt;3,&gt;=2.0.0-&gt;msal) (3.4.2)
# Requirement already satisfied: urllib3&lt;3,&gt;=1.21.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e950ac0f-d7a1-4bd2-ac8d-a26ee1eae11e/lib/python3.8/site-packages (from requests&lt;3,&gt;=2.0.0-&gt;msal) (2.2.3)
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Looking in indexes: http://repo.pgds.local/api/pypi/mgprupypi/simple
# Collecting azure-servicebus
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/fc/9e/37a27b8e575f88a7463e82d777651ebd8bedb77970f170819b1b3d176f96/azure_servicebus-7.14.2-py3-none-any.whl (411 kB)
# Collecting isodate&gt;=0.6.0
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/15/aa/0aca39a37d3c7eb941ba736ede56d689e7be91cab5d9ca846bde3999eba6/isodate-0.7.2-py3-none-any.whl (22 kB)
# Collecting azure-core&gt;=1.28.0
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/07/b7/76b7e144aa53bd206bf1ce34fa75350472c3f69bf30e5c8c18bc9881035d/azure_core-1.33.0-py3-none-any.whl (207 kB)
# Requirement already satisfied: typing-extensions&gt;=4.6.0 in /databricks/python3/lib/python3.8/site-packages (from azure-servicebus) (4.13.2)
# Requirement already satisfied: requests&gt;=2.21.0 in /databricks/python3/lib/python3.8/site-packages (from azure-core&gt;=1.28.0-&gt;azure-servicebus) (2.32.3)
# Requirement already satisfied: six&gt;=1.11.0 in /databricks/python3/lib/python3.8/site-packages (from azure-core&gt;=1.28.0-&gt;azure-servicebus) (1.15.0)
# Requirement already satisfied: idna&lt;4,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.21.0-&gt;azure-core&gt;=1.28.0-&gt;azure-servicebus) (2.10)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.21.0-&gt;azure-core&gt;=1.28.0-&gt;azure-servicebus) (2020.12.5)
# Requirement already satisfied: charset-normalizer&lt;4,&gt;=2 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.21.0-&gt;azure-core&gt;=1.28.0-&gt;azure-servicebus) (3.4.2)
# Requirement already satisfied: urllib3&lt;3,&gt;=1.21.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e950ac0f-d7a1-4bd2-ac8d-a26ee1eae11e/lib/python3.8/site-packages (from requests&gt;=2.21.0-&gt;azure-core&gt;=1.28.0-&gt;azure-servicebus) (2.2.3)
# Installing collected packages: isodate, azure-core, azure-servicebus
# Successfully installed azure-core-1.33.0 azure-servicebus-7.14.2 isodate-0.7.2
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Looking in indexes: http://repo.pgds.local/api/pypi/mgprupypi/simple
# Collecting requests_toolbelt
#   Downloading http://repo.pgds.local/api/pypi/mgprupypi/packages/packages/3f/51/d4db610ef29373b879047326cbf6fa98b6c1969d6f6dc423279de2b1be2c/requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Requirement already satisfied: requests&lt;3.0.0,&gt;=2.0.1 in /databricks/python3/lib/python3.8/site-packages (from requests_toolbelt) (2.32.3)
# Requirement already satisfied: idna&lt;4,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests&lt;3.0.0,&gt;=2.0.1-&gt;requests_toolbelt) (2.10)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests&lt;3.0.0,&gt;=2.0.1-&gt;requests_toolbelt) (2020.12.5)
# Requirement already satisfied: charset-normalizer&lt;4,&gt;=2 in /databricks/python3/lib/python3.8/site-packages (from requests&lt;3.0.0,&gt;=2.0.1-&gt;requests_toolbelt) (3.4.2)
# Requirement already satisfied: urllib3&lt;3,&gt;=1.21.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e950ac0f-d7a1-4bd2-ac8d-a26ee1eae11e/lib/python3.8/site-packages (from requests&lt;3.0.0,&gt;=2.0.1-&gt;requests_toolbelt) (2.2.3)
# Installing collected packages: requests-toolbelt
# Successfully installed requests-toolbelt-1.0.0
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Looking in indexes: http://repo.pgds.local/api/pypi/mgprupypi/simple
# Requirement already satisfied: openpyxl in /databricks/python3/lib/python3.8/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /databricks/python3/lib/python3.8/site-packages (from openpyxl) (2.0.0)
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Looking in indexes: http://repo.pgds.local/api/pypi/mgprupypi/simple
# Requirement already satisfied: requests_oauthlib in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e950ac0f-d7a1-4bd2-ac8d-a26ee1eae11e/lib/python3.8/site-packages (2.0.0)
# Requirement already satisfied: oauthlib&gt;=3.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e950ac0f-d7a1-4bd2-ac8d-a26ee1eae11e/lib/python3.8/site-packages (from requests_oauthlib) (3.2.2)
# Requirement already satisfied: requests&gt;=2.0.0 in /databricks/python3/lib/python3.8/site-packages (from requests_oauthlib) (2.32.3)
# Requirement already satisfied: idna&lt;4,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.0.0-&gt;requests_oauthlib) (2.10)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.0.0-&gt;requests_oauthlib) (2020.12.5)
# Requirement already satisfied: charset-normalizer&lt;4,&gt;=2 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.0.0-&gt;requests_oauthlib) (3.4.2)
# Requirement already satisfied: urllib3&lt;3,&gt;=1.21.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e950ac0f-d7a1-4bd2-ac8d-a26ee1eae11e/lib/python3.8/site-packages (from requests&gt;=2.0.0-&gt;requests_oauthlib) (2.2.3)
# Python interpreter will be restarted.
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %run ../credential
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import DatastreamPy as DSpy

from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lag
from pyspark.sql.window import Window
# from _datetime import datetime
import datetime
from dateutil.relativedelta import relativedelta, WE

import pandas as pd
pd.DataFrame.iteritems = pd.DataFrame.items
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ds = DSpy.DataClient(username=DS_user, password=DS_password)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# ds.get_data(tickers='LOPTDRV$LC', fields=['RIC','NAME'], kind=0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# ticker = 'LOPTBGULC'

lists = ['LOPTDRV$LC','LOPTDRV$LP','LOPTDRNLC','LOPTDRNLP']
lists = ['LOPTUPROLC','LOPTUPROLP','LOPTSPXULC','LOPTSPXULP']
meta_list = []
# Retrieve the constituent list
for clist in lists:
  data = ds.get_data(tickers=clist, fields=['RIC','NAME'], kind=0)

  meta_list.append(data)
data = pd.concat(meta_list)
# data = data.drop_duplicates(subset=['RIC'])



# Print the list of constituents
# data['Value'].to_list()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Instrument</th>
#       <th>Datatype</th>
#       <th>Value</th>
#       <th>Currency</th>
#     </tr>
#     <tr>
#       <th>Dates</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2025-05-02</th>
#       <td>AF12OY</td>
#       <td>RIC</td>
#       <td>UPROE162502500.U</td>
#       <td>U$</td>
#     </tr>
#     <tr>
#       <th>2025-05-02</th>
#       <td>AF12OZ</td>
#       <td>RIC</td>
#       <td>UPROE162503000.U</td>
#       <td>U$</td>
#     </tr>
#     <tr>
#       <th>2025-05-02</th>
#       <td>AF0LHG</td>
#       <td>RIC</td>
#       <td>UPROE162503500.U</td>
#       <td>U$</td>
#     </tr>
#     <tr>
#       <th>2025-05-02</th>
#       <td>AFXKIX</td>
#       <td>RIC</td>
#       <td>UPROE162504000.U</td>
#       <td>U$</td>
#     </tr>
#     <tr>
#       <th>2025-05-02</th>
#       <td>AFXKIY</td>
#       <td>RIC</td>
#       <td>UPROE162504500.U</td>
#       <td>U$</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2025-05-02</th>
#       <td>AF175T</td>
#       <td>NAME</td>
#       <td>PUT SPXU MAY27 43</td>
#       <td>U$</td>
#     </tr>
#     <tr>
#       <th>2025-05-02</th>
#       <td>AF175U</td>
#       <td>NAME</td>
#       <td>PUT SPXU MAY27 44</td>
#       <td>U$</td>
#     </tr>
#     <tr>
#       <th>2025-05-02</th>
#       <td>AF175V</td>
#       <td>NAME</td>
#       <td>PUT SPXU MAY27 45</td>
#       <td>U$</td>
#     </tr>
#     <tr>
#       <th>2025-05-02</th>
#       <td>AF175W</td>
#       <td>NAME</td>
#       <td>PUT SPXU MAY27 50</td>
#       <td>U$</td>
#     </tr>
#     <tr>
#       <th>2025-05-02</th>
#       <td>AF175X</td>
#       <td>NAME</td>
#       <td>PUT SPXU MAY27 55</td>
#       <td>U$</td>
#     </tr>
#   </tbody>
# </table>
# <p>2280 rows × 4 columns</p>
# </div>

# %%
data1 = data[data['Datatype']=='RIC']
data2 = data[data['Datatype']=='NAME']
data3 = data1.merge(data2,left_on='Instrument',right_on='Instrument')
data3 = data3[['Instrument','Value_x','Value_y']]
data3.columns = ['Instrument','RIC','NAME']
data3
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Instrument</th>
#       <th>RIC</th>
#       <th>NAME</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AF12OY</td>
#       <td>UPROE162502500.U</td>
#       <td>CALL UPRO MAY25 25</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AF12OZ</td>
#       <td>UPROE162503000.U</td>
#       <td>CALL UPRO MAY25 30</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AF0LHG</td>
#       <td>UPROE162503500.U</td>
#       <td>CALL UPRO MAY25 35</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AFXKIX</td>
#       <td>UPROE162504000.U</td>
#       <td>CALL UPRO MAY25 40</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>AFXKIY</td>
#       <td>UPROE162504500.U</td>
#       <td>CALL UPRO MAY25 45</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1135</th>
#       <td>AF175T</td>
#       <td>NA</td>
#       <td>PUT SPXU MAY27 43</td>
#     </tr>
#     <tr>
#       <th>1136</th>
#       <td>AF175U</td>
#       <td>NA</td>
#       <td>PUT SPXU MAY27 44</td>
#     </tr>
#     <tr>
#       <th>1137</th>
#       <td>AF175V</td>
#       <td>SPXUQ212704500.U</td>
#       <td>PUT SPXU MAY27 45</td>
#     </tr>
#     <tr>
#       <th>1138</th>
#       <td>AF175W</td>
#       <td>SPXUQ212705000.U</td>
#       <td>PUT SPXU MAY27 50</td>
#     </tr>
#     <tr>
#       <th>1139</th>
#       <td>AF175X</td>
#       <td>NA</td>
#       <td>PUT SPXU MAY27 55</td>
#     </tr>
#   </tbody>
# </table>
# <p>1140 rows × 3 columns</p>
# </div>

# %%
data3= data3[data3['RIC']!='NA']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data3[['CP','Under','Expire','Strike']] = data3['NAME'].str.split(' ',  expand=True)
data3
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1669508009450065&gt;:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3[[&#39;CP&#39;,&#39;Under&#39;,&#39;Expire&#39;,&#39;Strike&#39;]] = data3[&#39;NAME&#39;].str.split(&#39; &#39;,  expand=True)
# &lt;command-1669508009450065&gt;:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3[[&#39;CP&#39;,&#39;Under&#39;,&#39;Expire&#39;,&#39;Strike&#39;]] = data3[&#39;NAME&#39;].str.split(&#39; &#39;,  expand=True)
# &lt;command-1669508009450065&gt;:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3[[&#39;CP&#39;,&#39;Under&#39;,&#39;Expire&#39;,&#39;Strike&#39;]] = data3[&#39;NAME&#39;].str.split(&#39; &#39;,  expand=True)
# &lt;command-1669508009450065&gt;:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3[[&#39;CP&#39;,&#39;Under&#39;,&#39;Expire&#39;,&#39;Strike&#39;]] = data3[&#39;NAME&#39;].str.split(&#39; &#39;,  expand=True)
# Out[31]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Instrument</th>
#       <th>RIC</th>
#       <th>NAME</th>
#       <th>CP</th>
#       <th>Under</th>
#       <th>Expire</th>
#       <th>Strike</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AF12OY</td>
#       <td>UPROE162502500.U</td>
#       <td>CALL UPRO MAY25 25</td>
#       <td>CALL</td>
#       <td>UPRO</td>
#       <td>MAY25</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AF12OZ</td>
#       <td>UPROE162503000.U</td>
#       <td>CALL UPRO MAY25 30</td>
#       <td>CALL</td>
#       <td>UPRO</td>
#       <td>MAY25</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AF0LHG</td>
#       <td>UPROE162503500.U</td>
#       <td>CALL UPRO MAY25 35</td>
#       <td>CALL</td>
#       <td>UPRO</td>
#       <td>MAY25</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AFXKIX</td>
#       <td>UPROE162504000.U</td>
#       <td>CALL UPRO MAY25 40</td>
#       <td>CALL</td>
#       <td>UPRO</td>
#       <td>MAY25</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>AFXKIY</td>
#       <td>UPROE162504500.U</td>
#       <td>CALL UPRO MAY25 45</td>
#       <td>CALL</td>
#       <td>UPRO</td>
#       <td>MAY25</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1130</th>
#       <td>AF3PB6</td>
#       <td>SPXUQ212703000.U</td>
#       <td>PUT SPXU MAY27 30</td>
#       <td>PUT</td>
#       <td>SPXU</td>
#       <td>MAY27</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>1131</th>
#       <td>AF3PB7</td>
#       <td>SPXUQ212703500.U</td>
#       <td>PUT SPXU MAY27 35</td>
#       <td>PUT</td>
#       <td>SPXU</td>
#       <td>MAY27</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>1132</th>
#       <td>AF175Q</td>
#       <td>SPXUQ212704000.U</td>
#       <td>PUT SPXU MAY27 40</td>
#       <td>PUT</td>
#       <td>SPXU</td>
#       <td>MAY27</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>1137</th>
#       <td>AF175V</td>
#       <td>SPXUQ212704500.U</td>
#       <td>PUT SPXU MAY27 45</td>
#       <td>PUT</td>
#       <td>SPXU</td>
#       <td>MAY27</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>1138</th>
#       <td>AF175W</td>
#       <td>SPXUQ212705000.U</td>
#       <td>PUT SPXU MAY27 50</td>
#       <td>PUT</td>
#       <td>SPXU</td>
#       <td>MAY27</td>
#       <td>50</td>
#     </tr>
#   </tbody>
# </table>
# <p>1116 rows × 7 columns</p>
# </div>

# %%
# data3['Under'].unique()
Under_mapping = {'DRN':'Bear','DRV$':'Bull'}
Under_mapping = {'SPXU':'Bear','UPRO':'Bull'}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rics = data3['RIC'].to_list()
ric = rics[0]

def RIC2meta(ric):
  underlying=ric[:4]
  expire = ric[4:8]
  strick = int(ric[8:11])
  return(underlying,expire,strick)

RIC2meta(ric)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: (&#39;UPRO&#39;, &#39;E162&#39;, 502)</div>

# %%
start_date = datetime.date(datetime.date.today().year, datetime.date.today().month, 1).strftime('%Y-%m-%d')

ticker = rics

l = len(ticker)
step = 10
n_step = l//step + 1
df_list = []
for i in range(n_step):
  epoch = [f"<{x}>" for x in ticker[i*step:(i+1)*step]]

  # df = updater.ds.get_data(tickers=",".join(epoch), fields=["P"], start=start_date , end=end_date , freq="W")
  df  = ds.get_data(tickers=",".join(epoch), fields=['MP','VL','STRIKE_PRC','EXPIR_DATE'], start=start_date,kind=1).dropna() #,'PA','PB','MP'
  df_list.append(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(epoch[-1])
ds.get_data(epoch[-1], fields=['MP','VL','STRIKE_PRC','EXPIR_DATE'], start=start_date,kind=1).dropna()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;SPXUQ212705000.U&gt;
# Out[40]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>Instrument</th>
#       <th colspan="2" halign="left">&lt;SPXUQ212705000.U&gt;</th>
#     </tr>
#     <tr>
#       <th>Field</th>
#       <th>MP</th>
#       <th>VL</th>
#     </tr>
#     <tr>
#       <th>Currency</th>
#       <th>U$</th>
#       <th>U$</th>
#     </tr>
#     <tr>
#       <th>Dates</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2025-05-01</th>
#       <td>32.0</td>
#       <td>0.824</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
len(rics)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[41]: 1116</div>

# %%
df = pd.concat(df_list,axis = 1)
df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>Instrument</th>
#       <th>&lt;UPROE162502500.U&gt;</th>
#       <th>&lt;UPROE162503000.U&gt;</th>
#       <th>&lt;UPROE162503500.U&gt;</th>
#       <th>&lt;UPROE162504000.U&gt;</th>
#       <th>&lt;UPROE162504500.U&gt;</th>
#       <th>&lt;UPROE162505000.U&gt;</th>
#       <th>&lt;UPROE162505200.U&gt;</th>
#       <th>&lt;UPROE162505250.U&gt;</th>
#       <th>&lt;UPROE162505300.U&gt;</th>
#       <th>&lt;UPROE162505350.U&gt;</th>
#       <th>&lt;UPROE162502500.U&gt;</th>
#       <th>&lt;UPROE162503000.U&gt;</th>
#       <th>&lt;UPROE162503500.U&gt;</th>
#       <th>&lt;UPROE162504000.U&gt;</th>
#       <th>&lt;UPROE162504500.U&gt;</th>
#       <th>&lt;UPROE162505000.U&gt;</th>
#       <th>&lt;UPROE162505200.U&gt;</th>
#       <th>&lt;UPROE162505250.U&gt;</th>
#       <th>&lt;UPROE162505300.U&gt;</th>
#       <th>&lt;UPROE162505350.U&gt;</th>
#       <th>&lt;UPROE162505400.U&gt;</th>
#       <th>&lt;UPROE162505500.U&gt;</th>
#       <th>&lt;UPROE162505600.U&gt;</th>
#       <th>&lt;UPROE162505650.U&gt;</th>
#       <th>&lt;UPROE162505700.U&gt;</th>
#       <th>&lt;UPROE162505750.U&gt;</th>
#       <th>&lt;UPROE162505800.U&gt;</th>
#       <th>&lt;UPROE162505850.U&gt;</th>
#       <th>&lt;UPROE162505900.U&gt;</th>
#       <th>&lt;UPROE162506000.U&gt;</th>
#       <th>&lt;UPROE162505400.U&gt;</th>
#       <th>&lt;UPROE162505500.U&gt;</th>
#       <th>&lt;UPROE162505600.U&gt;</th>
#       <th>&lt;UPROE162505650.U&gt;</th>
#       <th>&lt;UPROE162505700.U&gt;</th>
#       <th>&lt;UPROE162505750.U&gt;</th>
#       <th>&lt;UPROE162505800.U&gt;</th>
#       <th>&lt;UPROE162505850.U&gt;</th>
#       <th>&lt;UPROE162505900.U&gt;</th>
#       <th>&lt;UPROE162506000.U&gt;</th>
#       <th>...</th>
#       <th>&lt;SPXUM152704300.U&gt;</th>
#       <th>&lt;SPXUM152704400.U&gt;</th>
#       <th>&lt;SPXUM152704500.U&gt;</th>
#       <th>&lt;SPXUM152704600.U&gt;</th>
#       <th>&lt;SPXUM152704700.U&gt;</th>
#       <th>&lt;SPXUM152704800.U&gt;</th>
#       <th>&lt;SPXUM152704900.U&gt;</th>
#       <th>&lt;SPXUM152705000.U&gt;</th>
#       <th>&lt;SPXUM152705500.U&gt;</th>
#       <th>&lt;SPXUP162701500.U&gt;</th>
#       <th>&lt;SPXUP162702000.U&gt;</th>
#       <th>&lt;SPXUP162702500.U&gt;</th>
#       <th>&lt;SPXUP162703000.U&gt;</th>
#       <th>&lt;SPXUP162703500.U&gt;</th>
#       <th>&lt;SPXUP162704000.U&gt;</th>
#       <th>&lt;SPXUP162704500.U&gt;</th>
#       <th>&lt;SPXUQ212701500.U&gt;</th>
#       <th>&lt;SPXUQ212702000.U&gt;</th>
#       <th>&lt;SPXUM152705500.U&gt;</th>
#       <th>&lt;SPXUP162701500.U&gt;</th>
#       <th>&lt;SPXUP162702000.U&gt;</th>
#       <th>&lt;SPXUP162702500.U&gt;</th>
#       <th>&lt;SPXUP162703000.U&gt;</th>
#       <th>&lt;SPXUP162703500.U&gt;</th>
#       <th>&lt;SPXUP162704000.U&gt;</th>
#       <th>&lt;SPXUP162704500.U&gt;</th>
#       <th>&lt;SPXUQ212701500.U&gt;</th>
#       <th>&lt;SPXUQ212702000.U&gt;</th>
#       <th>&lt;SPXUQ212702500.U&gt;</th>
#       <th>&lt;SPXUQ212703000.U&gt;</th>
#       <th>&lt;SPXUQ212703500.U&gt;</th>
#       <th>&lt;SPXUQ212704000.U&gt;</th>
#       <th>&lt;SPXUQ212704500.U&gt;</th>
#       <th>&lt;SPXUQ212705000.U&gt;</th>
#       <th>&lt;SPXUQ212702500.U&gt;</th>
#       <th>&lt;SPXUQ212703000.U&gt;</th>
#       <th>&lt;SPXUQ212703500.U&gt;</th>
#       <th>&lt;SPXUQ212704000.U&gt;</th>
#       <th>&lt;SPXUQ212704500.U&gt;</th>
#       <th>&lt;SPXUQ212705000.U&gt;</th>
#     </tr>
#     <tr>
#       <th>Field</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>...</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>MP</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#       <th>VL</th>
#     </tr>
#     <tr>
#       <th>Currency</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>...</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#       <th>U$</th>
#     </tr>
#     <tr>
#       <th>Dates</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th

# %%
df_p = df.stack(-3).reset_index()
df_p['Instrument'] = df_p['Instrument'].str.strip('<>')
df_p
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[43]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>Field</th>
#       <th>Dates</th>
#       <th>Instrument</th>
#       <th>MP</th>
#       <th>VL</th>
#     </tr>
#     <tr>
#       <th>Currency</th>
#       <th></th>
#       <th></th>
#       <th>U$</th>
#       <th>U$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2025-05-01</td>
#       <td>SPXU1A162600100.U</td>
#       <td>3.500</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2025-05-01</td>
#       <td>SPXU1A162600200.U</td>
#       <td>2.600</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2025-05-01</td>
#       <td>SPXU1A162600300.U</td>
#       <td>1.775</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2025-05-01</td>
#       <td>SPXU1A162600400.U</td>
#       <td>1.625</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2025-05-01</td>
#       <td>SPXU1A162600500.U</td>
#       <td>2.575</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2041</th>
#       <td>2025-05-02</td>
#       <td>UPROX192508400.U</td>
#       <td>18.450</td>
#       <td>0.5072</td>
#     </tr>
#     <tr>
#       <th>2042</th>
#       <td>2025-05-02</td>
#       <td>UPROX192508500.U</td>
#       <td>19.500</td>
#       <td>0.5225</td>
#     </tr>
#     <tr>
#       <th>2043</th>
#       <td>2025-05-02</td>
#       <td>UPROX192509000.U</td>
#       <td>21.800</td>
#       <td>0.4585</td>
#     </tr>
#     <tr>
#       <th>2044</th>
#       <td>2025-05-02</td>
#       <td>UPROX192509500.U</td>
#       <td>25.350</td>
#       <td>0.4363</td>
#     </tr>
#     <tr>
#       <th>2045</th>
#       <td>2025-05-02</td>
#       <td>UPROX192510000.U</td>
#       <td>29.350</td>
#       <td>0.4182</td>
#     </tr>
#   </tbody>
# </table>
# <p>2046 rows × 4 columns</p>
# </div>

# %%
df_p.columns = [x[0] for x in df_p.columns]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_full = df_p.merge(data3,left_on='Instrument',right_on='RIC')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
under_p = ds.get_data(tickers="U:SPXU,U:UPRO", fields=['P'], start=start_date,kind=1)
under_p = under_p.stack(-3).reset_index()
under_p.columns = [x[0] for x in under_p.columns]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_full['Under'].unique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[65]: array([&#39;SPXU&#39;, &#39;UPRO&#39;], dtype=object)</div>

# %%
under_p['Instrument'] = under_p['Instrument'].str.replace('U:','')
under_p
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[66]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dates</th>
#       <th>Instrument</th>
#       <th>P</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2025-05-01</td>
#       <td>SPXU</td>
#       <td>23.01</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2025-05-01</td>
#       <td>UPRO</td>
#       <td>68.92</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2025-05-02</td>
#       <td>SPXU</td>
#       <td>22.01</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2025-05-02</td>
#       <td>UPRO</td>
#       <td>71.91</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data_full = df_full.merge(under_p,left_on=['Under','Dates'],right_on=['Instrument','Dates'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data_full.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[68]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dates</th>
#       <th>Instrument_x</th>
#       <th>MP</th>
#       <th>VL</th>
#       <th>Instrument_y</th>
#       <th>RIC</th>
#       <th>NAME</th>
#       <th>CP</th>
#       <th>Under</th>
#       <th>Expire</th>
#       <th>Strike</th>
#       <th>Instrument</th>
#       <th>P</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2025-05-01</td>
#       <td>SPXU1A162600100.U</td>
#       <td>3.500</td>
#       <td>NaN</td>
#       <td>AC4FSC</td>
#       <td>SPXU1A162600100.U</td>
#       <td>CALL SPXU JAN26 1</td>
#       <td>CALL</td>
#       <td>SPXU</td>
#       <td>JAN26</td>
#       <td>1</td>
#       <td>SPXU</td>
#       <td>23.01</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2025-05-01</td>
#       <td>SPXU1A162600200.U</td>
#       <td>2.600</td>
#       <td>NaN</td>
#       <td>AC4FSZ</td>
#       <td>SPXU1A162600200.U</td>
#       <td>CALL SPXU JAN26 2</td>
#       <td>CALL</td>
#       <td>SPXU</td>
#       <td>JAN26</td>
#       <td>2</td>
#       <td>SPXU</td>
#       <td>23.01</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2025-05-01</td>
#       <td>SPXU1A162600300.U</td>
#       <td>1.775</td>
#       <td>NaN</td>
#       <td>AC4FTA</td>
#       <td>SPXU1A162600300.U</td>
#       <td>CALL SPXU JAN26 3</td>
#       <td>CALL</td>
#       <td>SPXU</td>
#       <td>JAN26</td>
#       <td>3</td>
#       <td>SPXU</td>
#       <td>23.01</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2025-05-01</td>
#       <td>SPXU1A162600400.U</td>
#       <td>1.625</td>
#       <td>NaN</td>
#       <td>AC4FTE</td>
#       <td>SPXU1A162600400.U</td>
#       <td>CALL SPXU JAN26 4</td>
#       <td>CALL</td>
#       <td>SPXU</td>
#       <td>JAN26</td>
#       <td>4</td>
#       <td>SPXU</td>
#       <td>23.01</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2025-05-01</td>
#       <td>SPXU1A162600500.U</td>
#       <td>2.575</td>
#       <td>NaN</td>
#       <td>AC4FTI</td>
#       <td>SPXU1A162600500.U</td>
#       <td>CALL SPXU JAN26 5</td>
#       <td>CALL</td>
#       <td>SPXU</td>
#       <td>JAN26</td>
#       <td>5</td>
#       <td>SPXU</td>
#       <td>23.01</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data_full.rename(columns={'MP':'Option_Price','VL':'IV','P':'Under_Price','Instrument_y':'Option_Code'},inplace=True)
data_full['Strike'] = data_full['Strike'].astype(float)
data_full['moneyness'] = data_full['Strike']/data_full['Under_Price']
data_full['CP_inverse'] = data_full['CP'].apply(lambda x: 'CALL' if x == 'PUT' else 'PUT')
data_full['moneyness_inverse'] = data_full['moneyness'].apply(lambda x: 1/x)
data_full
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out
0</td>
#       <td>UPRO</td>
#       <td>71.91</td>
#       <td>1.182033</td>
#       <td>CALL</td>
#       <td>0.846000</td>
#     </tr>
#     <tr>
#       <th>2043</th>
#       <td>2025-05-02</td>
#       <td>UPROX192509000.U</td>
#       <td>21.800</td>
#       <td>0.4585</td>
#       <td>AF7GQN</td>
#       <td>UPROX192509000.U</td>
#       <td>PUT UPRO DEC25 90</td>
#       <td>PUT</td>
#       <td>UPRO</td>
#       <td>DEC25</td>
#       <td>90.0</td>
#       <td>UPRO</td>
#       <td>71.91</td>
#       <td>1.251564</td>
#       <td>CALL</td>
#       <td>0.799000</td>
#     </tr>
#     <tr>
#       <th>2044</th>
#       <td>2025-05-02</td>
#       <td>UPROX192509500.U</td>
#       <td>25.350</td>
#       <td>0.4363</td>
#       <td>AF7GQO</td>
#       <td>UPROX192509500.U</td>
#       <td>PUT UPRO DEC25 95</td>
#       <td>PUT</td>
#       <td>UPRO</td>
#       <td>DEC25</td>
#       <td>95.0</td>
#       <td>UPRO</td>
#       <td>71.91</td>
#       <td>1.321096</td>
#       <td>CALL</td>
#       <td>0.756947</td>
#     </tr>
#     <tr>
#       <th>2045</th>
#       <td>2025-05-02</td>
#       <td>UPROX192510000.U</td>
#       <td>29.350</td>
#       <td>0.4182</td>
#       <td>AF7GQM</td>
#       <td>UPROX192510000.U</td>
#       <td>PUT UPRO DEC25 100</td>
#       <td>PUT</td>
#       <td>UPRO</td>
#       <td>DEC25</td>
#       <td>100.0</td>
#       <td>UPRO</td>
#       <td>71.91</td>
#       <td>1.390627</td>
#       <td>CALL</td>
#       <td>0.719100</td>
#     </tr>
#   </tbody>
# </table>
# <p>2046 rows × 16 columns</p>
# </div>

# %%
data_full['Under'].unique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[70]: array([&#39;SPXU&#39;, &#39;UPRO&#39;], dtype=object)</div>

# %%
data_1 = data_full[data_full['Under'] == 'SPXU'][['Dates','Option_Price','IV','RIC','Strike','Expire','Under','Under_Price','CP','moneyness','CP_inverse','moneyness_inverse']]
data_2 = data_full[data_full['Under'] == 'UPRO'][['Dates','Option_Price','IV','RIC','Strike','Expire','Under','Under_Price','CP','moneyness','CP_inverse','moneyness_inverse']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
join_tab = pd.merge_asof(data_1.sort_values('moneyness'),
                    data_2.sort_values('moneyness_inverse'), 
                    left_by=['Dates','CP','Expire'], 
                    left_on = ['moneyness'], 
                    right_by=['Dates','CP_inverse','Expire'], 
                    right_on = ['moneyness_inverse'], 
                    direction = 'nearest')
join_tab.dropna()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[72]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dates</th>
#       <th>Option_Price_x</th>
#       <th>IV_x</th>
#       <th>RIC_x</th>
#       <th>Strike_x</th>
#       <th>Expire</th>
#       <th>Under_x</th>
#       <th>Under_Price_x</th>
#       <th>CP_x</th>
#       <th>moneyness_x</th>
#       <th>CP_inverse_x</th>
#       <th>moneyness_inverse_x</th>
#       <th>Option_Price_y</th>
#       <th>IV_y</th>
#       <th>RIC_y</th>
#       <th>Strike_y</th>
#       <th>Under_y</th>
#       <th>Under_Price_y</th>
#       <th>CP_y</th>
#       <th>moneyness_y</th>
#       <th>CP_inverse_y</th>
#       <th>moneyness_inverse_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>42</th>
#       <td>2025-05-01</td>
#       <td>10.00</td>
#       <td>0.6931</td>
#       <td>SPXUF202501300.U</td>
#       <td>13.0</td>
#       <td>JUN25</td>
#       <td>SPXU</td>
#       <td>23.01</td>
#       <td>CALL</td>
#       <td>0.564972</td>
#       <td>PUT</td>
#       <td>1.770000</td>
#       <td>50.850</td>
#       <td>0.8436</td>
#       <td>UPROR202512000.U</td>
#       <td>120.0</td>
#       <td>UPRO</td>
#       <td>68.92</td>
#       <td>PUT</td>
#       <td>1.741149</td>
#       <td>CALL</td>
#       <td>0.574333</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td
.U</td>
#       <td>30.0</td>
#       <td>UPRO</td>
#       <td>68.92</td>
#       <td>CALL</td>
#       <td>0.435287</td>
#       <td>PUT</td>
#       <td>2.297333</td>
#     </tr>
#     <tr>
#       <th>801</th>
#       <td>2025-05-01</td>
#       <td>33.55</td>
#       <td>1.0604</td>
#       <td>SPXUM162605500.U</td>
#       <td>55.0</td>
#       <td>JAN26</td>
#       <td>SPXU</td>
#       <td>23.01</td>
#       <td>PUT</td>
#       <td>2.390265</td>
#       <td>CALL</td>
#       <td>0.418364</td>
#       <td>41.300</td>
#       <td>0.8578</td>
#       <td>UPROA162603000.U</td>
#       <td>30.0</td>
#       <td>UPRO</td>
#       <td>68.92</td>
#       <td>CALL</td>
#       <td>0.435287</td>
#       <td>PUT</td>
#       <td>2.297333</td>
#     </tr>
#     <tr>
#       <th>802</th>
#       <td>2025-05-02</td>
#       <td>1.59</td>
#       <td>0.9876</td>
#       <td>SPXUA162605500.U</td>
#       <td>55.0</td>
#       <td>JAN26</td>
#       <td>SPXU</td>
#       <td>22.01</td>
#       <td>CALL</td>
#       <td>2.498864</td>
#       <td>PUT</td>
#       <td>0.400182</td>
#       <td>1.850</td>
#       <td>0.8883</td>
#       <td>UPROM162603000.U</td>
#       <td>30.0</td>
#       <td>UPRO</td>
#       <td>71.91</td>
#       <td>PUT</td>
#       <td>0.417188</td>
#       <td>CALL</td>
#       <td>2.397000</td>
#     </tr>
#     <tr>
#       <th>803</th>
#       <td>2025-05-02</td>
#       <td>3.70</td>
#       <td>0.9028</td>
#       <td>SPXUA152705500.U</td>
#       <td>55.0</td>
#       <td>JAN27</td>
#       <td>SPXU</td>
#       <td>22.01</td>
#       <td>CALL</td>
#       <td>2.498864</td>
#       <td>PUT</td>
#       <td>0.400182</td>
#       <td>4.900</td>
#       <td>0.7715</td>
#       <td>UPROM152703000.U</td>
#       <td>30.0</td>
#       <td>UPRO</td>
#       <td>71.91</td>
#       <td>PUT</td>
#       <td>0.417188</td>
#       <td>CALL</td>
#       <td>2.397000</td>
#     </tr>
#   </tbody>
# </table>
# <p>704 rows × 22 columns</p>
# </div>

# %%
# from datetime import datetime
# date_string = "AUG25"
# datetime.strptime(date_string, "%b%y").replace( day=15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
join_tab['Expire_Date'] = join_tab['Expire'].apply(lambda x: datetime.datetime.strptime(x, "%b%y").replace( day=15))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
now = datetime.datetime.now()
join_tab['DTE'] = (join_tab['Expire_Date'] - now).dt.days
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import plotly.graph_objects as go
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# fig = go.Figure(data=[go.Surface(z=(join_tab['IV_x']-join_tab['IV_y']).values,x=join_tab['moneyness_x'].values,y=join_tab['IV_x'].values)])
# fig.update_traces(contours_z=dict(show=True, usecolormap=True,
#                                   highlightcolor="limegreen", project_z=True))
# fig.update_layout(title=dict(text='Mt Bruno Elevation'), autosize=False,
#                   scene_camera_eye=dict(x=1.87, y=0.88, z=-0.64),
#                   width=500, height=500,
#                   margin=dict(l=65, r=50, b=65, t=90)
# )

# fig.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
join_tab['Dates'].max()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[78]: &#39;2025-05-02&#39;</div>

# %%
import plotly.graph_objects as go
import numpy as np

date_slice = join_tab[(join_tab['Dates'] == join_tab['Dates'].max()) ] #& (join_tab['DTE'] == join_tab['DTE'].min())

x=date_slice['moneyness_x'].values
y=date_slice['DTE'].values
z=(date_slice['IV_x']-date_slice['IV_y']).values
fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z, mode='markers')])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="272c6987-7de1-4a7f-8fbe-0b706420ab0a" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
...

# %%
import numpy as np
import matplotlib.pyplot as plt
  
def end_v(under_x=23.97,under_y=66.14,op1_cp='CALL',op2_cp='PUT',op1_k=15.0,op2_k=105,op1_p=9,op2_p=38.8,ratio=3,expire = 'MAY25'):
  x_space = np.linspace(0.5, 2, 100)*under_x
  y_space = np.array([under_x*under_y/x for x in x_space])
  if op1_cp=='CALL':
    op1_pnl = np.maximum(x_space-op1_k,0)-op1_p
  else:
    op1_pnl = np.maximum(op1_k-x_space,0)-op1_p
  
  if op2_cp=='CALL':
    op2_pnl = np.maximum(y_space-op2_k,0)-op2_p
  else:
    op2_pnl = np.maximum(-y_space +op2_k,0)-op2_p
  
  pnl = op2_pnl - op1_pnl*ratio

  # Plot the P&L chart
  plt.figure(figsize=(10, 6))
  plt.plot(x_space, op1_pnl, label=f'Option1 SPXU {op1_cp} @{op1_k} P&L - {op1_p}')
  plt.plot(x_space, op2_pnl, label=f'Option2 UPRO {op2_cp} @{op2_k} P&L - {op2_p}')
  plt.plot(x_space, pnl, label='Strategy P&L')
  plt.axhline(0, color='black', linestyle='--')
  plt.axvline(under_x, color='red', linestyle='--', label='Strike Price')
  plt.title(f'P&L Chart, {expire} Ratio ={ratio}')
  plt.xlabel('Stock Price at Expiry')
  plt.ylabel('Profit & Loss')
  plt.legend()
  plt.grid(True)
  plt.show()
end_v()

# %%
for i in range(5):

  test = date_slice[((date_slice['IV_x']-date_slice['IV_y']) > 0.05)&(date_slice['moneyness_x']<1.5)&(date_slice['moneyness_x']>0.7)&(date_slice['CP_x']=='PUT')].iloc[i]
  under_x,under_y,op1_cp,op2_cp,op1_k,op2_k,op1_p,op2_p,expire = test[['Under_Price_x','Under_Price_y','CP_x','CP_y','Strike_x','Strike_y','Option_Price_x','Option_Price_y','Expire']]
  ratio = round(op2_k/op1_k)
  end_v(under_x,under_y,op1_cp,op2_cp,op1_k,op2_k,op1_p,op2_p,ratio,expire)

# %%
for i in range(5):

  test = date_slice[((date_slice['IV_x']-date_slice['IV_y']) < -0.02)&(date_slice['moneyness_x']<1.5)&(date_slice['moneyness_x']>0.7)&(date_slice['CP_x']=='PUT')].iloc[i]
  under_x,under_y,op1_cp,op2_cp,op1_k,op2_k,op1_p,op2_p,expire = test[['Under_Price_x','Under_Price_y','CP_x','CP_y','Strike_x','Strike_y','Option_Price_x','Option_Price_y','Expire']]
  ratio = round(op2_k/op1_k)
  end_v(under_x,under_y,op1_cp,op2_cp,op1_k,op2_k,op1_p,op2_p,ratio,expire)

# %%
date_slice[((date_slice['IV_x']-date_slice['IV_y']) > 0.05)]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[87]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dates</th>
#       <th>Option_Price_x</th>
#       <th>IV_x</th>
#       <th>RIC_x</th>
#       <th>Strike_x</th>
#       <th>Expire</th>
#       <th>Under_x</th>
#       <th>Under_Price_x</th>
#       <th>CP_x</th>
#       <th>moneyness_x</th>
#       <th>CP_inverse_x</th>
#       <th>moneyness_inverse_x</th>
#       <th>Option_Price_y</th>
#       <th>IV_y</th>
#       <th>RIC_y</th>
#       <th>Strike_y</th>
#       <th>Under_y</th>
#       <th>Under_Price_y</th>
#       <th>CP_y</th>
#       <th>moneyness_y</th>
#       <th>CP_inverse_y</th>
#       <th>moneyness_inverse_y</th>
#       <th>Expire_Date</th>
#       <th>DTE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th
td>
#       <td>SPXU</td>
#       <td>22.01</td>
#       <td>PUT</td>
#       <td>2.271695</td>
#       <td>CALL</td>
#       <td>0.440200</td>
#       <td>44.62</td>
#       <td>0.6841</td>
#       <td>UPROA152703000.U</td>
#       <td>30.0</td>
#       <td>UPRO</td>
#       <td>71.91</td>
#       <td>CALL</td>
#       <td>0.417188</td>
#       <td>PUT</td>
#       <td>2.397000</td>
#       <td>2027-01-15</td>
#       <td>619</td>
#     </tr>
#     <tr>
#       <th>791</th>
#       <td>2025-05-02</td>
#       <td>1.70</td>
#       <td>0.9402</td>
#       <td>SPXUA162605000.U</td>
#       <td>50.0</td>
#       <td>JAN26</td>
#       <td>SPXU</td>
#       <td>22.01</td>
#       <td>CALL</td>
#       <td>2.271695</td>
#       <td>PUT</td>
#       <td>0.440200</td>
#       <td>1.85</td>
#       <td>0.8883</td>
#       <td>UPROM162603000.U</td>
#       <td>30.0</td>
#       <td>UPRO</td>
#       <td>71.91</td>
#       <td>PUT</td>
#       <td>0.417188</td>
#       <td>CALL</td>
#       <td>2.397000</td>
#       <td>2026-01-15</td>
#       <td>254</td>
#     </tr>
#     <tr>
#       <th>802</th>
#       <td>2025-05-02</td>
#       <td>1.59</td>
#       <td>0.9876</td>
#       <td>SPXUA162605500.U</td>
#       <td>55.0</td>
#       <td>JAN26</td>
#       <td>SPXU</td>
#       <td>22.01</td>
#       <td>CALL</td>
#       <td>2.498864</td>
#       <td>PUT</td>
#       <td>0.400182</td>
#       <td>1.85</td>
#       <td>0.8883</td>
#       <td>UPROM162603000.U</td>
#       <td>30.0</td>
#       <td>UPRO</td>
#       <td>71.91</td>
#       <td>PUT</td>
#       <td>0.417188</td>
#       <td>CALL</td>
#       <td>2.397000</td>
#       <td>2026-01-15</td>
#       <td>254</td>
#     </tr>
#     <tr>
#       <th>803</th>
#       <td>2025-05-02</td>
#       <td>3.70</td>
#       <td>0.9028</td>
#       <td>SPXUA152705500.U</td>
#       <td>55.0</td>
#       <td>JAN27</td>
#       <td>SPXU</td>
#       <td>22.01</td>
#       <td>CALL</td>
#       <td>2.498864</td>
#       <td>PUT</td>
#       <td>0.400182</td>
#       <td>4.90</td>
#       <td>0.7715</td>
#       <td>UPROM152703000.U</td>
#       <td>30.0</td>
#       <td>UPRO</td>
#       <td>71.91</td>
#       <td>PUT</td>
#       <td>0.417188</td>
#       <td>CALL</td>
#       <td>2.397000</td>
#       <td>2027-01-15</td>
#       <td>619</td>
#     </tr>
#   </tbody>
# </table>
# <p>197 rows × 24 columns</p>
# </div>

# %%
date_slice
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[47]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dates</th>
#       <th>Option_Price_x</th>
#       <th>IV_x</th>
#       <th>RIC_x</th>
#       <th>Strike_x</th>
#       <th>Expire</th>
#       <th>Under_x</th>
#       <th>Under_Price_x</th>
#       <th>CP_x</th>
#       <th>moneyness_x</th>
#       <th>CP_inverse_x</th>
#       <th>moneyness_inverse_x</th>
#       <th>Option_Price_y</th>
#       <th>IV_y</th>
#       <th>RIC_y</th>
#       <th>Strike_y</th>
#       <th>Under_y</th>
#       <th>Under_Price_y</th>
#       <th>CP_y</th>
#       <th>moneyness_y</th>
#       <th>CP_inverse_y</th>
#       <th>moneyness_inverse_y</th>
#       <th>Expire_Date</th>
#       <th>DTE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th